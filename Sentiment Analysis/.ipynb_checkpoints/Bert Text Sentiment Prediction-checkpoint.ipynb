# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Обучение</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# # Проект для «Викишоп» с BERT

# %% [markdown]
# Интернет-магазин «Викишоп» запускает новый сервис. Теперь пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. То есть клиенты предлагают свои правки и комментируют изменения других. Магазину нужен инструмент, который будет искать токсичные комментарии и отправлять их на модерацию.
#
# Обучите модель классифицировать комментарии на позитивные и негативные. В вашем распоряжении набор данных с разметкой о токсичности правок.
#
# Постройте модель со значением метрики качества *F1* не меньше 0.75.
#
# **Инструкция по выполнению проекта**
#
# 1. Загрузите и подготовьте данные.
# 2. Обучите разные модели.
# 3. Сделайте выводы.
#
# Для выполнения проекта применять *BERT* необязательно, но вы можете попробовать.
#
# **Описание данных**
#
# Данные находятся в файле `toxic_comments.csv`. Столбец *text* в нём содержит текст комментария, а *toxic* — целевой признак.

# %%
# !pip install -r requirements.txt
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Users\datre\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\datre\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\datre\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\datre\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\datre\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\datre\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import transformers
import datasets
import string
import nltk

RANDOM_STATE = 42

from tqdm import notebook, tqdm
from nltk import word_tokenize
from nltk.probability import FreqDist
from sklearn.utils.class_weight import compute_class_weight
from nltk.corpus import stopwords
from wordcloud import WordCloud
from IPython.display import clear_output
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score
from torch.utils.data import Dataset, DataLoader
from transformers import TrainingArguments, BertTokenizer

# %% [markdown]
#
#
#
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
# 👍 - q
#
#
#
#
# <div class="alert alert-warning">
#
#
#
# Совет 🤔:
#
#
# По поводу констант, по правилам стилистики оставляем их сразу после импорта библиотек, так их будет проще контролировать

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студентаV1:</b> Привет, рад снова оказаться  у тебя на ревью, исправил константу.</div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Привет Лев!  Взаимно
#
#
# Константу выше поместить в отдельную ячейку
#
#
# <div class="alert alert-warning">
#
#
#
# Совет 🤔:
#
# Смотри что ещё можно сделать согласно PEP-8.  Видишь у тебя есть pip install. Допустим:
#
#
#     # pip install nltk # доустанавливаем необходимые библиотеки
#     # pip install pywsd
#     # pip install transformers
#
#
#
# Это значит что у нас сторонние библиотеки и значит
#
#
#
#     import transformers
#
# итд
#
# ставим в самый конец
#
# По аналогии можешь доисправить
#
#
#
# Если интересно можешь почитать [тут](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html)  подробнее

# %% [markdown]
# ## Подготовка

# %% [markdown]
# **Преобразуем столбец с метками классов к типу данных float32 для корректной работы функции потерь в дальнейшем**

# %%
data = pd.read_csv('toxic_comments.csv', index_col = 'Unnamed: 0')
data = data.rename(columns={'toxic': 'labels'})
data['labels'] = data['labels'].astype('float32')
data.head()
# Out:
#                                                 text  labels
# 0  Explanation\nWhy the edits made under my usern...     0.0
# 1  D'aww! He matches this background colour I'm s...     0.0
# 2  Hey man, I'm really not trying to edit war. It...     0.0
# 3  "\nMore\nI can't make any real suggestions on ...     0.0
# 4  You, sir, are my hero. Any chance you remember...     0.0

# %%
vc = data['labels'].value_counts()
vc
# Out:
# labels
# 0.0    143106
# 1.0     16186
# Name: count, dtype: int64

# %%
colors = sns.color_palette('pastel')
plt.pie(vc, autopct='%1.1f%%', labels=['Positive', 'Negative'], colors=colors)
plt.title('Распределение классов')
plt.show()

# %% [markdown]
# **В наших данных присутствует дисбаланс классов - токсичных комментариев намного меньше.**

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Совет 🤔:
#
#
#
#
# - стоило еще проверить на сбалансированность классов в таргете это важная информация при моделировании и  корректной оценки модели. и к нему график можно, ведь красивый, хорошо оформленный график может быть украшением проекта. Без учёта дисбаланса  предсказания модели могут быть смещены в сторону более часто встречающегося класса.  Для начала можно посмотреть [тут](https://pudie.ru/articles/707332/)
#
#
#
# - можно также посчитать количество слов в предложений,  длину слов в твите, опять же в разбивке по Таргету.  Если будут какие-то сильные отличия, возможно из-за этого стоит сгенерировать дополнительные признаки для наших моделей. Или например можно использовать библиотеку SentimentIntensityAnalyzer для оценки сантиментов, и посмотреть насколько хорошо ее оценки корелирует с нашими таргетами
#
#
# - когда мы работаем с текстами, describe итп описательные статистике не использовать, но можно провести частотный анализ текста.  Предлагаю для этого использовать [облако слов](https://habr.com/ru/post/517410/) - чтобы получить общее представление о тематике и о наиболее часто встречаемых словах в токсичных и нетоксичных твитах (в облаке уже автоматически будут убраны стоп слова). Кроме того графики, рисунки делают проект визуально интересней
#
#
# В тренажере облако импортируем так
#
#     !pip install wordcloud
#
#
# или
#
#     !pip install wordcloud==1.8.2.2
#
#
# И возможно дополнительно надо будет сделать
#
#
#
#     !pip install --upgrade Pillow  (попробуй версию 9.5.0)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студентаV1:</b> Добавил облако слов</div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Совет 🤔:
#
#
# Прекрасно, но стоило сделать отдельно для токсичных и нетоксичных, и было бы информативнее

# %% [markdown]
# **Проведем небольшой частотный анализ нашего набора данных и визуализируем результат с помощью облака слов**

# %%
data['text'][0:5] #текст до очистки
# Out:
# 0    Explanation\nWhy the edits made under my usern...
# 1    D'aww! He matches this background colour I'm s...
# 2    Hey man, I'm really not trying to edit war. It...
# 3    "\nMore\nI can't make any real suggestions on ...
# 4    You, sir, are my hero. Any chance you remember...
# Name: text, dtype: object

# %% [markdown]
# **Функция для удаления лишних символов из текста**

# %%
def remove_chars_from_text(text, chars):
    for ch in chars:
        text = text.replace('\n', ' ')
        text = text.replace(ch, '')
    return text

# %% [markdown]
# **Загрузка английских стоп-слов**

# %%
nltk.download('stopwords')
stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\datre\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
special_ch = string.punctuation + '\xa0«»\t—…' + string.digits
special_ch
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\xa0«»\t—…0123456789'

# %% [markdown]
# **Функция для подготовки текста к токенизации, очищаем тексты от специальных символов, приводим к нижнему регистру и удаляем стоп-слова**

# %%
def wordcloud_prep(text):
    prep_text = remove_chars_from_text(text, chars=special_ch)
    prep_text = prep_text.lower()
    prep_text = ' '.join(word for word in prep_text.split() if word not in stopwords)
    return prep_text

# %%
clear_text = data['text'].apply(wordcloud_prep)
clear_text[0:5]
# Out:
# 0    explanation edits made username hardcore metal...
# 1    daww matches background colour im seemingly st...
# 2    hey man im really trying edit war guy constant...
# 3    cant make real suggestions improvement wondere...
# 4                  sir hero chance remember page thats
# Name: text, dtype: object

# %% [markdown]
# **Объединяем тексты в одну строку и токенизируем для дальнейшего частотного анализа**

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\datre\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\datre\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text_for_wordcloud = ' '.join(clear_text)
text_tokens = word_tokenize(text_for_wordcloud)
fdist = FreqDist(nltk.Text(text_tokens))

# %%
plt.title('Частота распределения слов в тексте')
fdist.plot(30,cumulative=False);

# %% [markdown]
# **По графику видно, что чаще всего используются слова article, page, wikipedia, что вполне логично учитывая название магазина. Еще можно отметить, что на графике иллюстрируется закон Ципфа: частота использования слова убывает относительно его порядкового номера пропорционально 1/n**

# %% [markdown]
# **Для наглядности построим облако слов**

# %%
text_raw = " ".join(text_tokens)
wordcloud = WordCloud(width=800, height=400).generate(text_raw)

# %%
plt.figure(figsize=(10, 5))
plt.title('Облако слов')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off');

# %% [markdown]
# **Возьмем только 20000 объектов для более быстрого обучения модели.**

# %%
n = 20000
data = data.sample(n)

# %% [markdown]
# **Разобъем наши данные на выборки, учитывая дисбаланс классов с помощью стратификации.**

# %%
data_train, data_test = train_test_split(data, 
                                         test_size=0.2, 
                                         random_state=RANDOM_STATE, 
                                         stratify=data['labels'])
data_train.shape, data_test.shape
# Out:
# ((16000, 2), (4000, 2))

# %%
data_train['labels'].value_counts(normalize=True)
# Out:
# labels
# 0.0    0.9005
# 1.0    0.0995
# Name: proportion, dtype: float64

# %%
data_test['labels'].value_counts(normalize=True)
# Out:
# labels
# 0.0    0.9005
# 1.0    0.0995
# Name: proportion, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
# - random_state на месте
#
#
#
#
#
# - плюс за  проверку
#
#
#
#
#
# <div class="alert alert-warning">
#
#
#
# Совет:
#
#
#
#
#
#
#
# - обрати внимание на аргумент stratify, он позволит сохранить изначальное распределение таргетов во всех новых датасетах.  Существующий дисбаланс никуда не денется, но в каждом датасете он будет одинаковым. [Почитать](https://pythonru.com/baza-znanij/sklearn-train-test-split) можно тут

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студентаV1:</b> Исправил, добавил стратификацию.</div>

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# **Будем использовать более легкую модель DistilBert, так как другие обучаются слишком долго на CPU.**

# %%
model_id='bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_id)

# %%
model = transformers.BertForSequenceClassification.from_pretrained(model_id, 
                                                                   num_labels=1,
                                                                   hidden_dropout_prob=0.3,
                                                                   attention_probs_dropout_prob=0.3)
model.to(device);
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Совет 🤔:
#
#
# rubert  - это видимо модель обученная на русских массивах, а у нас 99,99% твитов на английском

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студентаV1:</b> Ой, исправил на подходящий токенайзер</div>

# %% [markdown]
# **Токенизируем текст и приведем его к тензорному виду для дальнейшего обучения.**

# %%
def preprocess_function(data):
   return tokenizer(data['text'], padding=True, truncation=True, add_special_tokens = True, max_length=128)
data_train = datasets.Dataset.from_pandas(data_train)
data_test = datasets.Dataset.from_pandas(data_test)
tokenized_train = data_train.map(preprocess_function, batched=True)
tokenized_test = data_test.map(preprocess_function, batched=True)
# Out:
# ...
# Map:   0%|          | 0/4000 [00:00<?, ? examples/s]

# %%
tokenized_train = tokenized_train.remove_columns(['text'])
tokenized_test = tokenized_test.remove_columns(['text']) 

tokenized_train.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
tokenized_test.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])

# %% [markdown]
# ## Обучение

# %% [markdown]
# **Разобъем датасеты на батчи с помощью PyTorch Dataloader**

# %%
BATCH_SIZE = 20

train_loader = DataLoader(tokenized_train, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(tokenized_test, batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# **Так как в нашей задаче два класса, то используем бинарную кросс-энтропию в качестве функции потерь, а так же передадим ей взвешенные классы.**

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(data_train['labels']), y=data_train['labels'])
class_weights
# Out:
# array([0.55524708, 5.02512563])

# %% [markdown]
# **Используем Mixed Precision Training для ускорения вычислений**

# %%
torch.cuda.is_available()
# Out:
# True

# %%
scaler = torch.amp.GradScaler('cuda')

# %% [markdown]
# **L2 регуляризацию зададим аргументом оптимизатора weight_decay, а так же выставим learning_rate**

# %%
weights = torch.tensor(class_weights, dtype=torch.float)
optimizer = optim.AdamW(model.parameters(), lr=1e-5, weight_decay=0.04)
loss_func = torch.nn.BCEWithLogitsLoss(pos_weight=weights[1])

# %%
EPOCHS = 7
LOG_EVERY = 10

train_losses_epoch = [] 
test_losses_epoch = [] 
test_accuracy = []
test_f1 = []

for epoch in range(EPOCHS):
    print(f'Epoch {epoch+1}/{EPOCHS}')

    model.train()
    total_loss_train = 0
    progress_bar = tqdm(train_loader, desc='Training')

    for step, batch in enumerate(progress_bar): 
        optimizer.zero_grad()
        
        inputs = batch['input_ids'].to(device)
        labels = batch['labels'].to(device)
        attention_mask = batch['attention_mask'].to(device)

        with torch.amp.autocast('cuda'):
            outputs = model(input_ids=inputs, attention_mask=attention_mask)
            logits = outputs.logits.squeeze(-1)
            loss_train = loss_func(logits, labels)
        
        scaler.scale(loss_train).backward()
        scaler.step(optimizer)
        scaler.update()
        
        total_loss_train += loss_train.item()
        
        
        if (step + 1) % LOG_EVERY == 0:
            progress_bar.set_postfix({'Loss': total_loss_train / (step + 1)})

    avg_train_loss = total_loss_train / len(train_loader)
    train_losses_epoch.append(avg_train_loss)

    
    model.eval()
    total_test_loss = 0
    predictions = [] 
    true_labels = []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc='Test'):
            inputs = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)
            attention_mask = batch['attention_mask'].to(device)

        
            outputs = model(input_ids=inputs, attention_mask=attention_mask)
            logits = outputs.logits.squeeze(-1)
            loss_test = loss_func(logits, labels)
                
            total_test_loss += loss_test.item()

            probs = torch.sigmoid(logits)  
            preds = (probs > 0.5).float() 
            
            predictions.extend(preds.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    avg_test_loss = total_test_loss / len(test_loader)
    test_losses_epoch.append(avg_test_loss)
 
    test_f1.append(f1_score(true_labels, predictions))
    test_accuracy.append(accuracy_score(true_labels, predictions))

    print(f'Train Loss = {avg_train_loss:.4f}, Test Loss = {avg_test_loss:.4f}, Test f1 = {f1_score(true_labels, predictions):.4f}, Test Accuracy = {accuracy_score(true_labels, predictions):.4f}')
# Out:
# Epoch 1/7
# ...
# Test: 100%|██████████| 200/200 [04:29<00:00,  1.35s/it]
# Train Loss = 0.4427, Test Loss = 0.3129, Test f1 = 0.6679, Test Accuracy = 0.9073
# Epoch 2/7
# ...
# Test: 100%|██████████| 200/200 [04:29<00:00,  1.35s/it]
# Train Loss = 0.2347, Test Loss = 0.2854, Test f1 = 0.7457, Test Accuracy = 0.9373
# Epoch 3/7
# ...
# Test: 100%|██████████| 200/200 [04:32<00:00,  1.36s/it]
# Train Loss = 0.1910, Test Loss = 0.2395, Test f1 = 0.7638, Test Accuracy = 0.9433
# Epoch 4/7
# ...
# Test: 100%|██████████| 200/200 [04:31<00:00,  1.36s/it]
# Train Loss = 0.1570, Test Loss = 0.2742, Test f1 = 0.7518, Test Accuracy = 0.9387
# Epoch 5/7
# ...
# Test: 100%|██████████| 200/200 [04:31<00:00,  1.36s/it]
# Train Loss = 0.1290, Test Loss = 0.3012, Test f1 = 0.7424, Test Accuracy = 0.9365
# Epoch 6/7
# ...
# Test: 100%|██████████| 200/200 [04:31<00:00,  1.36s/it]
# Train Loss = 0.1050, Test Loss = 0.2836, Test f1 = 0.7415, Test Accuracy = 0.9355
# Epoch 7/7
# ...
# Test: 100%|██████████| 200/200 [04:34<00:00,  1.37s/it]
# ...

# %% [markdown]
# **Для такого маленького сэмпла данных, за 7 эпох получен неплохой результат : f1 = 0.81**

# %% [markdown]
# **Визуализируем метрики качества и значение функции потерь по эпохам**

# %%
epochs = range(1, EPOCHS + 1)

plt.plot(epochs, train_losses_epoch, label='Train Loss', marker='o', linestyle='--')
plt.plot(epochs, test_losses_epoch, label='Test Loss', marker='o', linestyle='--')

plt.xlabel('Эпохи')
plt.ylabel('Значение функции потерь')
plt.title('Функция потерь')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, test_f1, label='Test F1-score', marker='s')
plt.plot(epochs, test_accuracy, label='Test Accuracy', marker='d')

plt.xlabel('Эпохи')
plt.ylabel('Значение метрик')
plt.title('Метрики качества на тестовом наборе данных')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Так как функция потерь на тестовом датасете сперва уменьшается, а затем увеличивается, то наша модель не в состоянии захватить все закономерности, BCEWithLogitsLoss(кросс-энтропия) наказывает модель за уверенные ошибки, даже если F1-score растёт**

# %% [markdown]
# **Напишем функцию для предсказания тональности текста и посмотрим за ее работой на примерах**

# %%
def predict_sentiment(model, text, tokenizer):
    model.eval()
    tokens = tokenizer(text, 
                       padding=True, 
                       truncation=True, 
                       add_special_tokens = True, 
                       max_length=128,
                       return_tensors='pt')
    
    input_ids = tokens['input_ids'].to(device)
    attention_mask = tokens['attention_mask'].to(device)
    output = model(input_ids=input_ids, attention_mask=attention_mask)
    logits = output.logits.squeeze(-1)
    prob = torch.sigmoid(logits).item()
    predicted_class = 'toxic' if prob > 0.5 else 'not_toxic'
    return {'text': text, 'probability': prob, 'predicted_class': predicted_class}

# %%
example_texts = ['OMG i like those <3', 'I WILL KILL YOUR FAMILY', 'Ahahaha, idc buddy, go fuck yourself']
for text in example_texts:
    prediction = predict_sentiment(model, text, tokenizer)
    print(f"Text: {prediction['text']}")
    print(f"Predicted Sentiment: {prediction['predicted_class']} (Probability: {prediction['probability']:.4f})")
# Out:
# Text: OMG i like those <3
# Predicted Sentiment: not_toxic (Probability: 0.0007)
# Text: I WILL KILL YOUR FAMILY
# Predicted Sentiment: toxic (Probability: 0.9984)
# Text: Ahahaha, idc buddy, go fuck yourself
# Predicted Sentiment: toxic (Probability: 0.9995)

# %% [markdown]
# **На примерах введеных вручную модель выдала корректные ответы**

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
# 👍Trainer
#
#
# <div class="alert alert-warning">
#
#
#
# Совет 🤔:
#
#
#
#
# Trainer это хорошо, код гораздо компактнее. С другой стороны весьма полезно написать  цикл со всеми стадиями обучения, и добавить график, для демонстрации улучшение метрики на валидационные выборке по итерациям

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студентаV1:</b> Исправил, это было сложно😓😓😓</div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Понимаю, ты выбрал самый сложный вариант. TFIDF, эмбединги Берта -  было реализовать проще. Но зато в цикле восстановил процесс обучения с движением по антиградиенту, обновление весов итд по кругу + график
#
# только на графике стоил использовать валидационный выборку.  И останавливать обучение в момент когда Метрика на валидационные выборки начинает падать (переобучение). А потом обученную модель применить на тестовой выборке и там смотреть на метрику

# %% [markdown]
# ## Выводы

# %% [markdown]
# **В данной работе мы разработали модель на основе HuggingFace BERT для обработки сообщений в сообществе интернет-магазина и определения их тональности(токсичное/не токсичное).
# Для достижения этой цели были выполнены следующие этапы:**
#
# * Было построено облако слов и частотное распределение
# * Данные были токенизированы с помощью BertTokenizer
# * Датасет подготовлен к работе с PyTorch с помощью функционала Datasets
# * Взяты 20000 примеров для обучения/тестирования
# * Реализована модель на основе transformers.BertForSequenceClassification и модели 'bert-base-uncased'
# * Для оптимизации градиентного спуска использовался AdamW, а в качестве функции потерь — BCEWithLogitsLoss, учитывающая дисбаланс классов
# * Вычисления были ускорены на GPU
# * В результате обучения получена модель с f1 метрикой ~0.82
# * На примерах показана работа модели

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет:
#
#
#
#
# Как мы можем использовать Берт?
#
#
# - Можем его использовать чтобы получить эмбединги и подать их в наши модели как альтернативу векторов от TFIDF/CountVectorizer (чтобы это реализовать можно взять готовый код в тренажёре) - Таким образом мы получаем, (если выбрать верную модель)  метрику за 0,9. Тут я бы тебе посоветовал оставить выборку в 2.000 примеров. А в качестве предобученной модели использовать /toxic-bert. Ещё Можно прикрутить использование GPU (Тогда весь код можно прогнать за 10-20 минут)
#
#
#
# - Можно тюнить модель Берта,  тут я видел метрику   за 0,8. Она достигается если оставить 20.000 примеров
#
#
#
#
# - Можно попробовать TFIDF, это устаревший подход, но зато есть возможность попрактиковаться в использовании связки pipeline+gridsearch и лемматизации (там есть свои тонкости). А в конце можно посмотреть какие слова модель считают наиболее важными. Там можно получить 0,75+, но для этого надо будет использовать всю выборку.  Для ускорения посоветовал бы использовать шустрые модели, типа Логистическая регрессии или вот такая  [моделька](https://medium.com/geekculture/passive-aggressive-algorithm-for-big-data-models-8cd535ceb2e6) (открывается с помощью VPN) [или](https://datafinder.ru/products/passivno-agressivnyy-klassifikator-v-mashinnom-obuchenii)
#
#
#
# Жду продолжение проекта

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студентаV1:</b> Вывод написан.</div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# 👍

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
# Спасибо за работу! Реализовал сложный вариант, и реализовал успешно. Здорово что попробовал многие желтые советы
#
# Отличная работа Лев. Желаю успехов в дальнейшей учебе!

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке исполнения
# - [ ]  Данные загружены и подготовлены
# - [ ]  Модели обучены
# - [ ]  Значение метрики *F1* не меньше 0.75
# - [ ]  Выводы написаны
